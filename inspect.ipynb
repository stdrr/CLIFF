# %%
import numpy as np

# %%
file_path = '/media/odin/stdrr/projects/tasks_on_human_meshes/code/CLIFF/data/test_samples/lspet_samples/lspet_samples_cliff_hr48.npz'
results = np.load(file_path)

# %%
results.keys()
# Out:
# KeysView(NpzFile '/media/odin/stdrr/projects/tasks_on_human_meshes/code/CLIFF/data/test_samples/lspet_samples/lspet_samples_cliff_hr48.npz' with keys: imgname, pose, shape, global_t, pred_joints...)

# %%
results['shape'].shape
# Out:
# (41, 10)

# %%
results['imgname'].shape
# Out:
# (17,)

# %%
import pickle

with open('/media/odin/stdrr/data/AGORA/labels/smplx_gt/all_volumes.pkl', 'rb') as f:
    all_vols = pickle.load(f)

# %%
all_vols.keys()
# Out:
# dict_keys(['trainset_3dpeople_adults_bfh', 'trainset_movedrenderpeople_kids_bfh', 'trainset_renderpeople_adults_body', 'trainset_movedrenderpeople_adults_bfh', 'trainset_renderpeople_p27_adults_bfh', 'trainset_renderpeople_kids_bfh', 'trainset_axyz_kids_body', 'trainset_renderpeople_p27_kids_bfh', 'trainset_3dpeople_kids_bfh', 'validationset_renderpeople_adults_bfh', 'trainset_humanalloy_adults_body', 'trainset_axyz_adults_bfh', 'trainset_axyz_adults_body', 'trainset_humanalloy_adults_bfh', 'trainset_axyz_kids_bfh', 'trainset_3dpeople_kids_body', 'trainset_3dpeople_adults_body', 'trainset_movedrenderpeople_adults_bfh_new', 'trainset_renderpeople_adults_bfh', 'trainset_renderpeople_p27_kids_body', 'trainset_renderpeople_kids_body', 'trainset_renderpeople_p27_adults_body'])

# %%
all_vols['validationset_renderpeople_adults_bfh']
# Out:
# {'rp_carla_posed_025_0_0': 0.0841,
#  'rp_eric_posed_037_0_0': 0.0999,
#  'rp_cindy_posed_024_0_0': 0.0656,
#  'rp_carla_posed_004_0_0': 0.0828,
#  'rp_ellie_posed_006_0_0': 0.0921,
#  'rp_alison_posed_027_0_0': 0.1212,
#  'rp_eric_posed_048_0_0': 0.1003,
#  'rp_pierre_posed_006_0_0': 0.0791,
#  'rp_stephanie_posed_015_0_0': 0.0922,
#  'rp_nathan_posed_013_0_0': 0.106,
#  'rp_nathan_posed_003_0_0': 0.1056,
#  'rp_alison_posed_008_0_0': 0.1056,
#  'rp_aaron_posed_015_0_0': 0.1003,
#  'rp_ellie_posed_003_0_0': 0.0856,
#  'rp_sydney_posed_024_0_0': 0.0751,
#  'rp_tiffany_posed_012_0_0': 0.0947,
#  'rp_eric_posed_047_0_0': 0.0979,
#  'rp_sydney_posed_022_0_0': 0.0669,
#  'rp_saki_posed_024_0_0': 0.081,
#  'rp_fiona_posed_017_0_0': 0.0821,
#  'rp_saki_posed_018_0_0': 0.0787,
#  'rp_luke_posed_006_0_0': 0.0926,
#  'rp_maria_posed_009_0_0': 0.0775,
#  'rp_nathan_posed_021_0_0': 0.1,
#  'rp_nathan_posed_014_0_0': 0.1025,
#  'rp_cindy_posed_014_0_0': 0.067,
# ...

# %%
all_shapes_path = '/media/odin/stdrr/data/AGORA/labels/smplx_gt/all_shapes.pkl'
with open(all_shapes_path, 'rb') as f:
    all_shapes = pickle.load(f)

# %%
all_shapes['validationset_renderpeople_bfh_flowers_5']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /media/odin/stdrr/projects/tasks_on_human_meshes/code/CLIFF/inspect.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bodin/media/odin/stdrr/projects/tasks_on_human_meshes/code/CLIFF/inspect.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> all_shapes['validationset_renderpeople_bfh_flowers_5']
#
# KeyError: 'validationset_renderpeople_bfh_flowers_5'

# %%
foo = '/media/odin/stdrr/data/AGORA/images/validation_images_1280x720/validation_images_1280x720_0/labels/validation_0_withjv_vol.pkl'
with open(foo, 'rb') as f:
    foo_ = pickle.load(f)

# %%
foo_.keys()
# Out:
# dict_keys(['ag_validationset_renderpeople_bfh_flowers_5_15_00000.png', 'ag_validationset_renderpeople_bfh_flowers_5_15_00001.png', 'ag_validationset_renderpeople_bfh_flowers_5_15_00002.png', 'ag_validationset_renderpeople_bfh_flowers_5_15_00003.png', 'ag_validationset_renderpeople_bfh_flowers_5_15_00004.png', 'ag_validationset_renderpeople_bfh_flowers_5_15_00005.png', 'ag_validationset_renderpeople_bfh_flowers_5_15_00006.png', 'ag_validationset_renderpeople_bfh_flowers_5_15_00007.png', 'ag_validationset_renderpeople_bfh_flowers_5_15_00008.png', 'ag_validationset_renderpeople_bfh_flowers_5_15_00009.png', 'ag_validationset_renderpeople_bfh_flowers_5_15_00010.png', 'ag_validationset_renderpeople_bfh_flowers_5_15_00011.png', 'ag_validationset_renderpeople_bfh_flowers_5_15_00012.png', 'ag_validationset_renderpeople_bfh_flowers_5_15_00013.png', 'ag_validationset_renderpeople_bfh_flowers_5_15_00014.png', 'ag_validationset_renderpeople_bfh_flowers_5_15_00015.png', 'ag_validationset_renderpeo
# ...

# %%
foo_['ag_validationset_renderpeople_bfh_flowers_5_15_00001.png']
# Out:
# {'volumes': [0.0843, 0.0506, 0.0571, 0.0527, 0.0768, 0.0849, 0.0888],
#  'keypoints': array([[[495.89730747, 411.58735909],
#          [492.70659444, 418.99371319],
#          [499.26046177, 418.53657179],
#          [498.02137732, 403.01061393],
#          [484.42483309, 447.87571002],
#          [506.01541468, 447.61541246],
#          [497.22902449, 391.3549091 ],
#          [489.08330958, 479.52311548],
#          [520.68639937, 474.06983381],
#          [496.32721881, 386.58372492],
#          [479.73343357, 483.43077483],
#          [516.53421283, 481.76570011],
#          [496.14435265, 368.97958373],
#          [492.26367985, 377.05141887],
#          [501.52562488, 376.55065039],
#          [493.32625235, 363.16627875],
#          [488.15287728, 376.05676248],
#          [507.99792057, 375.8822751 ],
#          [482.0742861 , 396.32635206],
#          [512.9958823 , 394.87252796],
#          [477.108979  , 414.97797348],
#          [508.5385605 , 413.92719677],
# ...
